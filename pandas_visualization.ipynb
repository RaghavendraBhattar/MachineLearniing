# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# import pandas as pd

# %matplotlib inline

# %%
df1 =pd.read_csv('/home/raghubhattar/Desktop/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df1', index_col=0)

# %%
df1.head()
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',
#        '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],
#       dtype='object', length=1000)

# %%
df2 = pd.read_csv('/home/raghubhattar/Desktop/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df2',index_col=0)

# %%
df2.head()
# Out:
#                  b         c         d
# a
# 0.039762  0.218517  0.103423  0.957904
# 0.937288  0.041567  0.899125  0.977680
# 0.780504  0.008948  0.557808  0.797510
# 0.672717  0.247870  0.264071  0.444358
# 0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area(alpa)
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2.plot.line(x=df2.index,y='B',figsize=(12,3),lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-10fa95b700f5> in <module>
# ----> 1 df2.plot.line(x=df2.index,y='B',figsize=(12,3),lw=1)
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in line(self, x, y, **kwargs)
#    1015         as coordinates.
#    1016         """
# -> 1017         return self(kind="line", x=x, y=y, **kwargs)
#    1018
#    1019     @Appender(
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     912                 if is_integer(x) and not data.columns.holds_integer():
#     913                     x = data_cols[x]
# --> 914                 elif not isinstance(data[x], ABCSeries):
#     915                     raise ValueError("x must be a label or position")
#     916                 data = data.set_index(x)
#
# ...

# %%
df1.plot.scatter(x='A', y='B', c='C')
# Out:
# /home/raghubhattar/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*50)
# Out:
# /home/raghubhattar/.local/lib/python3.8/site-packages/matplotlib/collections.py:1003: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
 df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
# Out:
# /home/raghubhattar/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
